# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine

# %%
df = pd.read_csv(r'D:\Data Analysis\1.Projects\4.NBA Player Stats\all_seasons.csv')

# %%
pd.set_option('display.max.rows', 200)
pd.set_option('display.max.columns', 50)

# %%
df.head()
# Out:
#    Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0           0  Randy Livingston               HOU  22.0         193.04
# 1           1  Gaylon Nickerson               WAS  28.0         190.50
# 2           2      George Lynch               VAN  26.0         203.20
# 3           3    George McCloud               LAL  30.0         203.20
# 4           4      George Zidek               DEN  23.0         213.36
#
#    player_weight                college country draft_year draft_round  \
# 0      94.800728        Louisiana State     USA       1996           2
# 1      86.182480  Northwestern Oklahoma     USA       1994           2
# 2     103.418976         North Carolina     USA       1993           1
# 3     102.058200          Florida State     USA       1989           1
# 4     119.748288                   UCLA     USA       1995           1
#
#   draft_number  gp   pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         12844 non-null  int64
#  1   player_name        12844 non-null  object
#  2   team_abbreviation  12844 non-null  object
#  3   age                12844 non-null  float64
#  4   player_height      12844 non-null  float64
#  5   player_weight      12844 non-null  float64
#  6   college            10990 non-null  object
#  7   country            12844 non-null  object
#  8   draft_year         12844 non-null  object
#  9   draft_round        12844 non-null  object
#  10  draft_number       12844 non-null  object
#  11  gp                 12844 non-null  int64
#  12  pts                12844 non-null  float64
#  13  reb                12844 non-null  float64
#  14  ast                12844 non-null  float64
#  15  net_rating         12844 non-null  float64
# ...

# %%
df = df.set_index('Unnamed: 0')

# %%
df.head()
# Out:
#                  player_name team_abbreviation   age  player_height  \
# Unnamed: 0
# 0           Randy Livingston               HOU  22.0         193.04
# 1           Gaylon Nickerson               WAS  28.0         190.50
# 2               George Lynch               VAN  26.0         203.20
# 3             George McCloud               LAL  30.0         203.20
# 4               George Zidek               DEN  23.0         213.36
#
#             player_weight                college country draft_year  \
# Unnamed: 0
# 0               94.800728        Louisiana State     USA       1996
# 1               86.182480  Northwestern Oklahoma     USA       1994
# 2              103.418976         North Carolina     USA       1993
# 3              102.058200          Florida State     USA       1989
# 4              119.748288                   UCLA     USA       1995
#
#            draft_round draft_number  gp   pts  reb  ast  net_rating  oreb_pct  \
# Unnamed: 0
# ...

# %%
df = df.round(3)

# %%
username = "root"
password = "Sanchahe851225"
host = "localhost"
port = "3306"
database = "nba_player_stats"

# Create connection engine
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
# Export to sql
df.to_sql(
    name="all_players",   # Table name
    con=engine,
    if_exists="replace",              # or "append" to add without deleting existing
    index=False,                      # Avoid exporting pandas index
    chunksize=1000                    # Handle large datasets in batches
)
# Out:
# 12844
